# %%
import pandas as pd
url='https://raw.githubusercontent.com/codebasics/py/refs/heads/master/ML/14_naive_bayes/titanic.csv'
df=pd.read_csv(url)
df.head(2)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import pandas as pd
#       2 url='https://raw.githubusercontent.com/codebasics/py/refs/heads/master/ML/14_naive_bayes/titanic.csv'
#       3 df=pd.read_csv(url)
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df.drop(['PassengerId','Name','SibSp','Parch','Ticket','Cabin','Embarked'],axis='columns',inplace=True)
df.head()
# Out:
#    Pclass     Sex   Age     Fare  Survived
# 0       3    male  22.0   7.2500         0
# 1       1  female  38.0  71.2833         1
# 2       3  female  26.0   7.9250         1
# 3       1  female  35.0  53.1000         1
# 4       3    male  35.0   8.0500         0

# %%
inputs=df.drop('Survived',axis='columns')
target=df.Survived

# %%
dummies=pd.get_dummies(inputs.Sex)
dummies.head(3)
# Out:
#    female   male
# 0   False   True
# 1    True  False
# 2    True  False

# %%
inputs=pd.concat([inputs,dummies],axis='columns')
inputs.head(3)
# Out:
#    Pclass     Sex   Age     Fare  female   male
# 0       3    male  22.0   7.2500   False   True
# 1       1  female  38.0  71.2833    True  False
# 2       3  female  26.0   7.9250    True  False

# %%
inputs.drop(['Sex','male'],axis='columns',inplace=True)
inputs.head(3)
# Out:
#    Pclass   Age     Fare  female
# 0       3  22.0   7.2500   False
# 1       1  38.0  71.2833    True
# 2       3  26.0   7.9250    True

# %%
inputs.columns[inputs.isna().any()]
# Out:
# Index(['Age'], dtype='object')

# %%
inputs.Age[:10]
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# 5     NaN
# 6    54.0
# 7     2.0
# 8    27.0
# 9    14.0
# Name: Age, dtype: float64

# %%
inputs.Age=inputs.Age.fillna(inputs.Age.mean())
inputs.head()
# Out:
#    Pclass   Age     Fare  female
# 0       3  22.0   7.2500   False
# 1       1  38.0  71.2833    True
# 2       3  26.0   7.9250    True
# 3       1  35.0  53.1000    True
# 4       3  35.0   8.0500   False

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(inputs,target,test_size=0.3)

# %%
from sklearn.naive_bayes import GaussianNB
model=GaussianNB()

# %%
model.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
model.score(X_test,y_test)
# Out:
# 0.7574626865671642

# %%
X_test[0:10]
# Out:
#      Pclass        Age      Fare  female
# 603       3  44.000000    8.0500   False
# 758       3  34.000000    8.0500   False
# 67        3  19.000000    8.1583   False
# 561       3  40.000000    7.8958   False
# 96        1  71.000000   34.6542   False
# 303       2  29.699118   12.3500    True
# 0         3  22.000000    7.2500   False
# 809       1  33.000000   53.1000    True
# 505       1  18.000000  108.9000   False
# 260       3  29.699118    7.7500   False

# %%
model.predict(X_test[0:10])
# Out:
# array([0, 0, 0, 0, 0, 1, 0, 1, 1, 0])

# %%
model.predict_proba(X_test[:10])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 model.predict_proba(X_test[:10])
#
# NameError: name 'model' is not defined

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(GaussianNB(),X_train,y_train,cv=5)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from sklearn.model_selection import cross_val_score
#       2 cross_val_score(GaussianNB(),X_train,y_train,cv=5)
#
# ModuleNotFoundError: No module named 'sklearn'
